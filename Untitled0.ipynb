# %% [markdown]
# <a href="https://colab.research.google.com/github/JessaSobrepena20/Renaming-Deleting-Missing-Data/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/JessaSobrepena20/Renaming-Deleting-Missing-Data/main/RailsToTrails_National%20Count%20Data_week.xlsx%20-%20Total%20Count%20data%20(31%20counters).csv')

# %%
df.head()
# Out:
#   Timeframe Week of   2019 counts (31 counters)   2020 counts (31 counters)  \
# 0    Week 1  30-Dec                      167679                      183546
# 1    Week 2   6-Jan                       82340                       97140
# 2    Week 3  13-Jan                       62315                       75782
# 3    Week 4  20-Jan                       75801                       83809
# 4    Week 5  27-Jan                       75841                       94738
#
#    2021 Counts Change 2019-2020  Unnamed: 6  Unnamed: 7 Unnamed: 8  Unnamed: 9
# 0          NaN               9%    1.094627         NaN        NaN         NaN
# 1          NaN              18%  117.974253         NaN        NaN         NaN
# 2          NaN              22%  121.611169         NaN        NaN         NaN
# 3          NaN              11%  110.564504         NaN        NaN         NaN
# 4          NaN              25%  124.916602         NaN        NaN         NaN

# %%
# Remove unnecessary columns
df = df.drop(columns=['Unnamed: 7'])
df.head()
# Out:
#   Timeframe Week of   2019 counts (31 counters)   2020 counts (31 counters)  \
# 0    Week 1  30-Dec                      167679                      183546
# 1    Week 2   6-Jan                       82340                       97140
# 2    Week 3  13-Jan                       62315                       75782
# 3    Week 4  20-Jan                       75801                       83809
# 4    Week 5  27-Jan                       75841                       94738
#
#    2021 Counts Change 2019-2020  Unnamed: 6 Unnamed: 8  Unnamed: 9
# 0          NaN               9%    1.094627        NaN         NaN
# 1          NaN              18%  117.974253        NaN         NaN
# 2          NaN              22%  121.611169        NaN         NaN
# 3          NaN              11%  110.564504        NaN         NaN
# 4          NaN              25%  124.916602        NaN         NaN

# %%
# Remove unnecessary columns
df = df.drop(columns=['Unnamed: 8'])
df.head()
# Out:
#   Timeframe Week of   2019 counts (31 counters)   2020 counts (31 counters)  \
# 0    Week 1  30-Dec                      167679                      183546
# 1    Week 2   6-Jan                       82340                       97140
# 2    Week 3  13-Jan                       62315                       75782
# 3    Week 4  20-Jan                       75801                       83809
# 4    Week 5  27-Jan                       75841                       94738
#
#    2021 Counts Change 2019-2020  Unnamed: 6  Unnamed: 9
# 0          NaN               9%    1.094627         NaN
# 1          NaN              18%  117.974253         NaN
# 2          NaN              22%  121.611169         NaN
# 3          NaN              11%  110.564504         NaN
# 4          NaN              25%  124.916602         NaN

# %%
# Remove unnecessary columns
df = df.drop(columns=['Unnamed: 9'])
df.head()
# Out:
#   Timeframe Week of   2019 counts (31 counters)   2020 counts (31 counters)  \
# 0    Week 1  30-Dec                      167679                      183546
# 1    Week 2   6-Jan                       82340                       97140
# 2    Week 3  13-Jan                       62315                       75782
# 3    Week 4  20-Jan                       75801                       83809
# 4    Week 5  27-Jan                       75841                       94738
#
#    2021 Counts Change 2019-2020  Unnamed: 6
# 0          NaN               9%    1.094627
# 1          NaN              18%  117.974253
# 2          NaN              22%  121.611169
# 3          NaN              11%  110.564504
# 4          NaN              25%  124.916602

# %%
# DataFrame before renaming columns
df.head()
# Out:
#   Timeframe Week of   2019 counts (31 counters)   2020 counts (31 counters)  \
# 0    Week 1  30-Dec                      167679                      183546
# 1    Week 2   6-Jan                       82340                       97140
# 2    Week 3  13-Jan                       62315                       75782
# 3    Week 4  20-Jan                       75801                       83809
# 4    Week 5  27-Jan                       75841                       94738
#
#    2021 Counts Change 2019-2020  Unnamed: 6
# 0          NaN               9%    1.094627
# 1          NaN              18%  117.974253
# 2          NaN              22%  121.611169
# 3          NaN              11%  110.564504
# 4          NaN              25%  124.916602

# %%
# this wont work as there is a space in the column name
df.Unnamed:6

# %%
# Approach 1 dictionary subtitution using rename method
df=df.rename(columns={'Unnamed; 6':'percent_change'})
#DataFrame after renaming columns
df.head()
# Out:
#   Timeframe Week of   2019 counts (31 counters)   2020 counts (31 counters)  \
# 0    Week 1  30-Dec                      167679                      183546
# 1    Week 2   6-Jan                       82340                       97140
# 2    Week 3  13-Jan                       62315                       75782
# 3    Week 4  20-Jan                       75801                       83809
# 4    Week 5  27-Jan                       75841                       94738
#
#    2021 Counts Change 2019-2020  Unnamed: 6
# 0          NaN               9%    1.094627
# 1          NaN              18%  117.974253
# 2          NaN              22%  121.611169
# 3          NaN              11%  110.564504
# 4          NaN              25%  124.916602
